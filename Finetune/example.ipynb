# %% [markdown]
# # Linear probing

# %%
# !python finetune.py \
    --device 0 --epochs 50 \
    --dataset 'bace' --input_model_file 'MORE.pth' --filename 'example' \
    --seed 42 --split 'scaffold' --eval_train --ft_type 'freeze' --run_cv 1
# Out:
# [args]
# Namespace(device=0, batch_size=32, epochs=50, lr=0.001, lr_scale=1, decay=0, num_layer=5, emb_dim=300, dropout_ratio=0.5, graph_pooling='mean', JK='last', gnn_type='gin', dataset='bace', input_model_file='MORE.pth', filename='example', seed=42, runseed=-1, split='scaffold', num_workers=0, eval_train=True, ft_type='freeze', run_cv=1, seed_list_in='', seed_list=[])
#
# ================== 1 exec - RANDOM seed ==================
# ### Setup Dataset ###
# [dataset]
# MoleculeDataset(1513)
# scaffold spllit ...
# [train_dataset example]
# Data(y=[1], edge_attr=[66, 2], id=[1], x=[31, 2], edge_index=[2, 66], fold=[1])
# ### Setup Model ###
# Load Pretrained parameter ...
# <All keys matched successfully>
# Loaded Pretrained parameter !!!
# [model]
# GNN_graphpred(
#   (gnn): GNN(
#     (x_embedding1): Embedding(120, 300)
#     (x_embedding2): Embedding(8, 300)
#     (gnns): ModuleList(
#       (0): GINConv()
#       (1): GINConv()
#       (2): GINConv()
#       (3): GINConv()
# ...

# %% [markdown]
# # Full fine-tuning

# %%
# !python finetune.py \
    --device 0 --epochs 50 \
    --dataset 'bace' --input_model_file 'MORE.pth' --filename 'example' \
    --seed 42 --split 'scaffold' --eval_train --ft_type 'full' --run_cv 1

# %% [markdown]
# # w/o Pretrain

# %%
# !python finetune.py \
    --device 0 --epochs 50 \
    --dataset 'bace' --input_model_file 'MORE.pth' --filename 'example' \
    --seed 42 --split 'scaffold' --eval_train --ft_type 'no_pretrain' --run_cv 1
